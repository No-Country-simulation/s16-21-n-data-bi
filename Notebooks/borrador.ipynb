# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carga de dataset
df = pd.read_csv("../../data/data_latinoamerica.csv", usecols=range(10))
df.sample(10)
# Out:
#          location_key        date country_code        country_name  \
# 2660943  BR_MG_316540  2020-04-18           BR              Brazil
# 2993772  BR_PA_150170  2022-08-10           BR              Brazil
# 2437646  BR_MG_314625  2022-02-16           BR              Brazil
# 7310514   CO_63_63190  2022-06-17           CO            Colombia
# 180588       AR_D_063  2020-08-14           AR           Argentina
# 5897843  BR_SP_355090  2021-02-06           BR              Brazil
# 2701006  BR_MG_316880  2021-06-15           BR              Brazil
# 7654954         DO_08  2021-04-15           DO  Dominican Republic
# 2752688  BR_MS_500070  2021-11-12           BR              Brazil
# 9416182  MX_PUE_21089  2021-11-22           MX              Mexico
#
#          new_confirmed  new_deceased  cumulative_confirmed  \
# 2660943            0.0           0.0                   0.0
# 2993772           26.0           0.0                7385.0
# ...

# %%
df=df[df['location_key']=='AR']

# %%
df
# Out:
#     location_key        date country_code country_name  new_confirmed  \
# 0             AR  2020-01-01           AR    Argentina            3.0
# 1             AR  2020-01-02           AR    Argentina           14.0
# 2             AR  2020-01-03           AR    Argentina            3.0
# 3             AR  2020-01-04           AR    Argentina            7.0
# 4             AR  2020-01-05           AR    Argentina            5.0
# ..           ...         ...          ...          ...            ...
# 986           AR  2022-09-13           AR    Argentina            0.0
# 987           AR  2022-09-14           AR    Argentina            NaN
# 988           AR  2022-09-15           AR    Argentina            NaN
# 989           AR  2022-09-16           AR    Argentina            NaN
# 990           AR  2022-09-17           AR    Argentina            NaN
#
#      new_deceased  cumulative_confirmed  cumulative_deceased  \
# 0             0.0                   3.0                  0.0
# ...

# %%
df.loc[:, 'vaccine'] = df['cumulative_vaccine_doses_administered'].diff()

# %%
df
# Out:
#     location_key        date country_code country_name  new_confirmed  \
# 0             AR  2020-01-01           AR    Argentina            3.0
# 1             AR  2020-01-02           AR    Argentina           14.0
# 2             AR  2020-01-03           AR    Argentina            3.0
# 3             AR  2020-01-04           AR    Argentina            7.0
# 4             AR  2020-01-05           AR    Argentina            5.0
# ..           ...         ...          ...          ...            ...
# 986           AR  2022-09-13           AR    Argentina            0.0
# 987           AR  2022-09-14           AR    Argentina            NaN
# 988           AR  2022-09-15           AR    Argentina            NaN
# 989           AR  2022-09-16           AR    Argentina            NaN
# 990           AR  2022-09-17           AR    Argentina            NaN
#
#      new_deceased  cumulative_confirmed  cumulative_deceased  \
# 0             0.0                   3.0                  0.0
# ...

# %%
df[['location_key','date','new_confirmed', 'new_deceased','cumulative_vaccine_doses_administered','vaccine']].iloc[860:900]
# Out:
#     location_key        date  new_confirmed  new_deceased  \
# 860           AR  2022-05-10         5014.0           5.0
# 861           AR  2022-05-11         5469.0           1.0
# 862           AR  2022-05-12         5661.0           4.0
# 863           AR  2022-05-13         5595.0           5.0
# 864           AR  2022-05-14         3190.0           5.0
# 865           AR  2022-05-15         2569.0           5.0
# 866           AR  2022-05-16         6378.0           7.0
# 867           AR  2022-05-17         5969.0           4.0
# 868           AR  2022-05-18         3071.0           4.0
# 869           AR  2022-05-19         8670.0           8.0
# 870           AR  2022-05-20         7514.0           4.0
# 871           AR  2022-05-21         4482.0           5.0
# 872           AR  2022-05-22         3176.0           6.0
# 873           AR  2022-05-23         9592.0           7.0
# 874           AR  2022-05-24         8249.0           7.0
# ...
