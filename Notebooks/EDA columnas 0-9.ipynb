# %% [markdown]
# # Columnas 0 - 9

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carga de dataset
df = pd.read_csv("../../data/data_latinoamerica.csv", usecols=range(10))
df.sample(10)
# Out:
#          location_key        date country_code country_name  new_confirmed  \
# 5878428  BR_SP_354910  2022-03-18           BR       Brazil           52.0
# 9962813  MX_VER_30118  2020-10-17           MX       Mexico            NaN
# 3447418  BR_PE_260970  2021-12-21           BR       Brazil            0.0
# 4082694  BR_PR_412480  2022-02-04           BR       Brazil           21.0
# 2054453  BR_MG_311430  2020-04-20           BR       Brazil            0.0
# 5813389  BR_SP_354320  2020-07-02           BR       Brazil            0.0
# 8812042  MX_OAX_20051  2020-03-11           MX       Mexico            NaN
# 1742884  BR_MA_210330  2021-12-07           BR       Brazil            2.0
# 3600522  BR_PI_220375  2020-08-07           BR       Brazil            1.0
# 6853566   CO_19_19290  2022-03-12           CO     Colombia            NaN
#
#          new_deceased  cumulative_confirmed  cumulative_deceased  \
# 5878428           0.0               13992.0                358.0
# 9962813           NaN                   NaN                  NaN
# 3447418           0.0                1333.0                 29.0
# 4082694           0.0                2054.0                 26.0
# 2054453           0.0                   0.0                  0.0
# 5813389           0.0                   6.0                  0.0
# 8812042           NaN                   NaN                  NaN
# 1742884          -1.0                3595.0                221.0
# 3600522           0.0                  27.0                  1.0
# 6853566           NaN                   NaN                  NaN
#
#          cumulative_vaccine_doses_administered  population
# 5878428                                    NaN     83639.0
# 9962813                                    NaN    118907.0
# 3447418                                    NaN     22878.0
# 4082694                                    NaN     10599.0
# 2054453                                    NaN     29735.0
# 5813389                                    NaN      4446.0
# 8812042                                    NaN      4347.0
# 1742884                                    NaN    118038.0
# 3600522                                    NaN      5074.0
# 6853566                                    NaN         NaN

# %%
df.head()
# Out:
#   location_key        date country_code country_name  new_confirmed  \
# 0           AR  2020-01-01           AR    Argentina            3.0
# 1           AR  2020-01-02           AR    Argentina           14.0
# 2           AR  2020-01-03           AR    Argentina            3.0
# 3           AR  2020-01-04           AR    Argentina            7.0
# 4           AR  2020-01-05           AR    Argentina            5.0
#
#    new_deceased  cumulative_confirmed  cumulative_deceased  \
# 0           0.0                   3.0                  0.0
# 1           0.0                  17.0                  0.0
# 2           0.0                  20.0                  0.0
# 3           0.0                  27.0                  0.0
# 4           0.0                  32.0                  0.0
#
#    cumulative_vaccine_doses_administered  population
# 0                                    NaN  44938712.0
# 1                                    NaN  44938712.0
# 2                                    NaN  44938712.0
# 3                                    NaN  44938712.0
# 4                                    NaN  44938712.0

# %%
df.tail()
# Out:
#          location_key        date country_code country_name  new_confirmed  \
# 12216052         VE_Z  2022-09-13           VE    Venezuela            NaN
# 12216053         VE_Z  2022-09-14           VE    Venezuela            NaN
# 12216054         VE_Z  2022-09-15           VE    Venezuela            NaN
# 12216055         VE_Z  2022-09-16           VE    Venezuela            NaN
# 12216056         VE_Z  2022-09-17           VE    Venezuela            NaN
#
#           new_deceased  cumulative_confirmed  cumulative_deceased  \
# 12216052           NaN                   NaN                  NaN
# 12216053           NaN                   NaN                  NaN
# 12216054           NaN                   NaN                  NaN
# 12216055           NaN                   NaN                  NaN
# 12216056           NaN                   NaN                  NaN
#
#           cumulative_vaccine_doses_administered  population
# 12216052                                    NaN   1422000.0
# 12216053                                    NaN   1422000.0
# 12216054                                    NaN   1422000.0
# 12216055                                    NaN   1422000.0
# 12216056                                    NaN   1422000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12216057 entries, 0 to 12216056
# Data columns (total 10 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   location_key                           object
#  1   date                                   object
#  2   country_code                           object
#  3   country_name                           object
#  4   new_confirmed                          float64
#  5   new_deceased                           float64
#  6   cumulative_confirmed                   float64
#  7   cumulative_deceased                    float64
#  8   cumulative_vaccine_doses_administered  float64
#  9   population                             float64
# dtypes: float64(6), object(4)
# memory usage: 932.0+ MB

# %%
df.describe(include='object')
# Out:
#        location_key        date country_code country_name
# count      12216057    12216057     12216057     12216057
# unique        12327         991           20           20
# top              AR  2020-01-01           BR       Brazil
# freq            991       12327      5565456      5565456

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#        new_confirmed  new_deceased  cumulative_confirmed  cumulative_deceased  \
# count     6377003.00    6322319.00            6377372.00           6322681.00
# mean           31.95          0.70              12074.47               333.55
# std           774.77         18.10             266649.49              6907.97
# min        -73907.00      -4109.00                  0.00                 0.00
# 25%             0.00          0.00                147.00                 3.00
# 50%             0.00          0.00                606.00                12.00
# 75%             4.00          0.00               1993.00                42.00
# max        298408.00      11447.00           34568833.00            685203.00
#
#        cumulative_vaccine_doses_administered   population
# count                              267929.00  11683890.00
# mean                              1670412.04    140654.87
# std                              13949509.24   2446017.36
# min                                     0.00         4.00
# 25%                                  4032.00      4533.00
# 50%                                 15402.00     11405.00
# 75%                                 71278.00     29504.00
# max                             347868481.00 212559409.00

# %%
unique_counts = df.nunique()

# Mostrar el número de valores únicos por columna
print("Número de valores únicos por columna:")
print(unique_counts)
# Out:
# Número de valores únicos por columna:
# location_key                              12327
# date                                        991
# country_code                                 20
# country_name                                 20
# new_confirmed                              9845
# new_deceased                               1287
# cumulative_confirmed                     137782
# cumulative_deceased                       26579
# cumulative_vaccine_doses_administered    110038
# population                                10055
# dtype: int64

# %%
# Ver la cantidad de valores nulos por columna
total_filas = df.shape[0]

nulos_por_columna = df.isnull().sum()
porcentaje_nulos = (nulos_por_columna / total_filas) * 100

print("Valores nulos por columna:")
nulos_por_columna
# Out:
# Valores nulos por columna:
# location_key                                    0
# date                                            0
# country_code                                    0
# country_name                                    0
# new_confirmed                             5839054
# new_deceased                              5893738
# cumulative_confirmed                      5838685
# cumulative_deceased                       5893376
# cumulative_vaccine_doses_administered    11948128
# population                                 532167
# dtype: int64

# %%
print("Porcentaje de valores nulos por columna:")
porcentaje_nulos
# Out:
# Porcentaje de valores nulos por columna:
# location_key                             0.00
# date                                     0.00
# country_code                             0.00
# country_name                             0.00
# new_confirmed                           47.80
# new_deceased                            48.25
# cumulative_confirmed                    47.80
# cumulative_deceased                     48.24
# cumulative_vaccine_doses_administered   97.81
# population                               4.36
# dtype: float64

# %%
df.columns
# Out:
# Index(['location_key', 'date', 'country_code', 'country_name', 'new_confirmed',
#        'new_deceased', 'cumulative_confirmed', 'cumulative_deceased',
#        'cumulative_vaccine_doses_administered', 'population'],
#       dtype='object')

# %%
# Convertir la columna 'date' a formato datetime
df['date'] = pd.to_datetime(df['date'])

# Agrupar por fecha y obtener sumas diarias de casos confirmados y fallecimientos
daily_data = df.groupby('date')[['new_confirmed', 'new_deceased']].sum().reset_index()

# Visualizar las tendencias temporales
plt.figure(figsize=(15, 5))
plt.plot(daily_data['date'], daily_data['new_confirmed'], label='Nuevos Confirmados')
plt.plot(daily_data['date'], daily_data['new_deceased'], label='Nuevos Fallecidos')
plt.title('Tendencias Temporales de Casos Confirmados y Fallecidos')
plt.xlabel('Fecha')
plt.ylabel('Cantidad')
plt.legend()
plt.show()

# %%
# Convertir la columna 'date' a formato datetime
df['date'] = pd.to_datetime(df['date'])

# Agrupar por fecha y obtener sumas diarias de casos confirmados y fallecimientos
daily_data = df.groupby('date')[['new_confirmed', 'new_deceased']].sum().reset_index()

# Visualizar las tendencias temporales de casos confirmados
plt.figure(figsize=(15, 5))
plt.plot(daily_data['date'], daily_data['new_confirmed'], label='Nuevos Confirmados', color='blue')
plt.title('Tendencias Temporales de Casos Confirmados')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de Nuevos Casos Confirmados')
plt.legend()
plt.show()

# Visualizar las tendencias temporales de fallecimientos
plt.figure(figsize=(15, 5))
plt.plot(daily_data['date'], daily_data['new_deceased'], label='Nuevos Fallecidos', color='red')
plt.title('Tendencias Temporales de Fallecimientos')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de Nuevos Fallecimientos')
plt.legend()
plt.show()

# %%
# Convertir la columna 'date' a formato datetime
df['date'] = pd.to_datetime(df['date'])

# Agrupar por fecha y obtener sumas diarias de casos confirmados y fallecimientos acumulados
daily_data = df.groupby('date')[['cumulative_confirmed', 'cumulative_deceased']].sum().reset_index()

# Visualizar las tendencias temporales de casos confirmados acumulados
plt.figure(figsize=(15, 5))
plt.plot(daily_data['date'], daily_data['cumulative_confirmed'], label='Casos Confirmados Acumulados', color='blue')
plt.title('Tendencias Temporales de Casos Confirmados Acumulados')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de Casos Confirmados Acumulados')
plt.legend()
plt.show()

# Visualizar las tendencias temporales de fallecimientos acumulados
plt.figure(figsize=(15, 5))
plt.plot(daily_data['date'], daily_data['cumulative_deceased'], label='Fallecimientos Acumulados', color='red')
plt.title('Tendencias Temporales de Fallecimientos Acumulados')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de Fallecimientos Acumulados')
plt.legend()
plt.show()

# %%
# Agrupar por fecha y obtener la suma diaria de dosis de vacunas administradas acumuladas
daily_data = df.groupby('date')['cumulative_vaccine_doses_administered'].sum().reset_index()

# Visualizar las tendencias temporales de dosis de vacunas administradas acumuladas
plt.figure(figsize=(15, 5))
plt.plot(daily_data['date'], daily_data['cumulative_vaccine_doses_administered'], label='Dosis de Vacunas Administradas Acumuladas', color='green')
plt.title('Tendencias Temporales de Dosis de Vacunas Administradas Acumuladas')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de Dosis de Vacunas Administradas Acumuladas')
plt.legend()
plt.show()
