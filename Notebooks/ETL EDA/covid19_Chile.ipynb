# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../../data/data_latinoamerica.csv")

# %%
df = df[df['location_key'] == 'CL']

# %%
df
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6115461           CL  2020-01-01           CL        Chile           0.00
# 6115462           CL  2020-01-02           CL        Chile           0.00
# 6115463           CL  2020-01-03           CL        Chile           0.00
# 6115464           CL  2020-01-04           CL        Chile           0.00
# 6115465           CL  2020-01-05           CL        Chile           0.00
# ...              ...         ...          ...          ...            ...
# 6116447           CL  2022-09-13           CL        Chile        1906.00
# 6116448           CL  2022-09-14           CL        Chile            NaN
# 6116449           CL  2022-09-15           CL        Chile            NaN
# 6116450           CL  2022-09-16           CL        Chile            NaN
# 6116451           CL  2022-09-17           CL        Chile            NaN
#
#          new_deceased  cumulative_confirmed  cumulative_deceased  \
# 6115461          0.00                  0.00                 0.00
# 6115462          0.00                  0.00                 0.00
# 6115463          0.00                  0.00                 0.00
# 6115464          0.00                  0.00                 0.00
# 6115465          0.00                  0.00                 0.00
# ...               ...                   ...                  ...
# 6116447         10.00            4568495.00             60822.00
# 6116448           NaN                   NaN                  NaN
# 6116449           NaN                   NaN                  NaN
# 6116450           NaN                   NaN                  NaN
# 6116451           NaN                   NaN                  NaN
#
#          cumulative_vaccine_doses_administered  population  ...  \
# 6115461                                    NaN 17574003.00  ...
# 6115462                                    NaN 17574003.00  ...
# 6115463                                    NaN 17574003.00  ...
# 6115464                                    NaN 17574003.00  ...
# 6115465                                    NaN 17574003.00  ...
# ...                                        ...         ...  ...
# 6116447                            62204235.00 17574003.00  ...
# 6116448                                    NaN 17574003.00  ...
# 6116449                                    NaN 17574003.00  ...
# 6116450                                    NaN 17574003.00  ...
# 6116451                                    NaN 17574003.00  ...
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6115461               6723516.00         709418.00          12027.00
# 6115462               6723516.00         709418.00          12027.00
# 6115463               6723516.00         709418.00          12027.00
# 6115464               6723516.00         709418.00          12027.00
# 6115465               6723516.00         709418.00          12027.00
# ...                          ...               ...               ...
# 6116447               6723516.00         709418.00          12027.00
# 6116448               6723516.00         709418.00          12027.00
# 6116449               6723516.00         709418.00          12027.00
# 6116450               6723516.00         709418.00          12027.00
# 6116451               6723516.00         709418.00          12027.00
#
#          life_expectancy  adult_male_mortality_rate  \
# 6115461            80.04                     107.67
# 6115462            80.04                     107.67
# 6115463            80.04                     107.67
# 6115464            80.04                     107.67
# 6115465            80.04                     107.67
# ...                  ...                        ...
# 6116447            80.04                     107.67
# 6116448            80.04                     107.67
# 6116449            80.04                     107.67
# 6116450            80.04                     107.67
# 6116451            80.04                     107.67
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6115461                        59.03                     25.30
# 6115462                        59.03                     25.30
# 6115463                        59.03                     25.30
# 6115464                        59.03                     25.30
# 6115465                        59.03                     25.30
# ...                              ...                       ...
# 6116447                        59.03                     25.30
# 6116448                        59.03                     25.30
# 6116449                        59.03                     25.30
# 6116450                        59.03                     25.30
# 6116451                        59.03                     25.30
#
#          comorbidity_mortality_rate  new_recovered  cumulative_recovered
# 6115461                       12.40            NaN                   NaN
# 6115462                       12.40            NaN                   NaN
# 6115463                       12.40            NaN                   NaN
# 6115464                       12.40            NaN                   NaN
# 6115465                       12.40            NaN                   NaN
# ...                             ...            ...                   ...
# 6116447                       12.40           0.00                   NaN
# 6116448                       12.40            NaN                   NaN
# 6116449                       12.40            NaN                   NaN
# 6116450                       12.40            NaN                   NaN
# 6116451                       12.40            NaN                   NaN
#
# [991 rows x 50 columns]

# %% [markdown]
# ### Contar cuantos valores Nulos tiene cada columna

# %%
# Contar cuántas filas contienen valores nulos en cada columna
null_counts = df.isnull().sum()

# Filtrar solo las columnas que tienen valores nulos
columns_with_nulls = null_counts[null_counts > 0]

# Mostrar el recuento de filas con valores nulos por columna
print("Columns with null values and their counts:")
print(columns_with_nulls)
# Out:
# Columns with null values and their counts:
# new_confirmed                              4
# new_deceased                               4
# cumulative_confirmed                       4
# cumulative_deceased                        4
# cumulative_vaccine_doses_administered    376
# average_temperature_celsius                6
# minimum_temperature_celsius                6
# maximum_temperature_celsius                6
# rainfall_mm                                6
# relative_humidity                          6
# new_recovered                             66
# cumulative_recovered                     899
# dtype: int64

# %% [markdown]
# ### Contar cuantos 0 tiene cada columna

# %%
# Contar cuántas filas contienen valores 0 en cada columna
columns_with_zeros = df.columns[(df == 0).any()]

# Crear un diccionario para almacenar el recuento de filas con valores 0
zero_counts = {column: (df[column] == 0).sum() for column in columns_with_zeros}

# Mostrar el recuento de filas con valores 0 por columna
print("\nColumns with zero values and their counts:")
for column, count in zero_counts.items():
    print(f"Column '{column}' has {count} rows with zero values.")

# Opcional: mostrar el diccionario completo de ceros
print("\nCounts of zero values per column:", zero_counts)
# Out:
# Columns with zero values and their counts:
# Column 'new_confirmed' has 61 rows with zero values.
# Column 'new_deceased' has 87 rows with zero values.
# Column 'cumulative_confirmed' has 57 rows with zero values.
# Column 'cumulative_deceased' has 81 rows with zero values.
# Column 'rainfall_mm' has 678 rows with zero values.
# Column 'new_recovered' has 848 rows with zero values.
# Column 'cumulative_recovered' has 15 rows with zero values.
#
# Counts of zero values per column: {'new_confirmed': 61, 'new_deceased': 87, 'cumulative_confirmed': 57, 'cumulative_deceased': 81, 'rainfall_mm': 678, 'new_recovered': 848, 'cumulative_recovered': 15}

# %% [markdown]
# # Transformacion de DF

# %% [markdown]
# #### Realizo un filtrado debido que anterior y posterior a estas fechas hay valores nulos y/o datos errones

# %%
# Definir el rango de fechas
start_date = '2020-01-01'
end_date = '2022-08-31'

# Filtrar el DataFrame para mantener las filas dentro del rango de fechas
df_cl = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# %% [markdown]
# #### Elimino estas columnas por:
# #### las 2 primeras columnas tienen valores errones
# #### la 3ra columna tiene muchos valores en 0
# #### la 4 y 5ta columna tienen puros valores nulos
# #### la 6 y 7ma columna no concuerdan con el de poblacion
# #### Prefiero trabajar con el promedio de la temperatura del dia

# %%
columns_to_drop = [
    'cumulative_confirmed', 
    'cumulative_deceased', 
    'rainfall_mm', 
    'new_recovered',
    'cumulative_recovered',
    'population_rural',
    'population_urban', 
    'minimum_temperature_celsius', 
    'maximum_temperature_celsius'
]

# Eliminar las columnas
df_cl = df_cl.copy()
df_cl.drop(columns=columns_to_drop, inplace=True)

# %%
df_cl.head()
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6115461           CL  2020-01-01           CL        Chile           0.00
# 6115462           CL  2020-01-02           CL        Chile           0.00
# 6115463           CL  2020-01-03           CL        Chile           0.00
# 6115464           CL  2020-01-04           CL        Chile           0.00
# 6115465           CL  2020-01-05           CL        Chile           0.00
#
#          new_deceased  cumulative_vaccine_doses_administered  population  \
# 6115461          0.00                                    NaN 17574003.00
# 6115462          0.00                                    NaN 17574003.00
# 6115463          0.00                                    NaN 17574003.00
# 6115464          0.00                                    NaN 17574003.00
# 6115465          0.00                                    NaN 17574003.00
#
#          population_male  population_female  ...  average_temperature_celsius  \
# 6115461       8972014.00         8601989.00  ...                        20.80
# 6115462       8972014.00         8601989.00  ...                        19.89
# 6115463       8972014.00         8601989.00  ...                        20.14
# 6115464       8972014.00         8601989.00  ...                        21.08
# 6115465       8972014.00         8601989.00  ...                        19.46
#
#          relative_humidity  population_largest_city  area_rural_sq_km  \
# 6115461              57.37               6723516.00         709418.00
# 6115462              62.00               6723516.00         709418.00
# 6115463              65.80               6723516.00         709418.00
# 6115464              65.11               6723516.00         709418.00
# 6115465              64.95               6723516.00         709418.00
#
#          area_urban_sq_km  life_expectancy  adult_male_mortality_rate  \
# 6115461          12027.00            80.04                     107.67
# 6115462          12027.00            80.04                     107.67
# 6115463          12027.00            80.04                     107.67
# 6115464          12027.00            80.04                     107.67
# 6115465          12027.00            80.04                     107.67
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6115461                        59.03                     25.30
# 6115462                        59.03                     25.30
# 6115463                        59.03                     25.30
# 6115464                        59.03                     25.30
# 6115465                        59.03                     25.30
#
#          comorbidity_mortality_rate
# 6115461                       12.40
# 6115462                       12.40
# 6115463                       12.40
# 6115464                       12.40
# 6115465                       12.40
#
# [5 rows x 41 columns]

# %%
# Contar cuántas filas contienen valores nulos en cada columna
null_counts = df_cl.isnull().sum()

# Filtrar solo las columnas que tienen valores nulos
columns_with_nulls = null_counts[null_counts > 0]

# Mostrar el recuento de filas con valores nulos por columna
print("Columns with null values and their counts:")
print(columns_with_nulls)
# Out:
# Columns with null values and their counts:
# cumulative_vaccine_doses_administered    372
# average_temperature_celsius                2
# relative_humidity                          2
# dtype: int64

# %%
# Contar cuántas filas contienen valores 0 en cada columna
columns_with_zeros = df_cl.columns[(df_cl == 0).any()]

# Crear un diccionario para almacenar el recuento de filas con valores 0
zero_counts = {column: (df_cl[column] == 0).sum() for column in columns_with_zeros}

# Mostrar el recuento de filas con valores 0 por columna
print("\nColumns with zero values and their counts:")
for column, count in zero_counts.items():
    print(f"Column '{column}' has {count} rows with zero values.")

# Opcional: mostrar el diccionario completo de ceros
print("\nCounts of zero values per column:", zero_counts)
# Out:
# Columns with zero values and their counts:
# Column 'new_confirmed' has 61 rows with zero values.
# Column 'new_deceased' has 87 rows with zero values.
#
# Counts of zero values per column: {'new_confirmed': 61, 'new_deceased': 87}

# %% [markdown]
# #### Vamos a imputar las columnas que tienen valores nulos y ceros

# %%
# Imputación con la media para columnas específicas
df_cl.loc[:, 'average_temperature_celsius'] = df_cl['average_temperature_celsius'].fillna(df_cl['average_temperature_celsius'].mean())
df_cl.loc[:, 'relative_humidity'] = df_cl['relative_humidity'].fillna(df_cl['relative_humidity'].mean())

# %%
# Rellenar con 0 donde la fecha sea menor a '2021-02-17'
fecha_limite = '2020-12-29'
df_cl.loc[df['date'] < fecha_limite] = df_cl.loc[df['date'] < fecha_limite].fillna(0)

# %%
# Contar cuántas filas contienen valores 0 en cada columna
columns_with_zeros = df.columns[(df == 0).any()]

# Crear un diccionario para almacenar el recuento de filas con valores 0
zero_counts = {column: (df[column] == 0).sum() for column in columns_with_zeros}

# Mostrar el recuento de filas con valores 0 por columna
print("\nColumns with zero values and their counts:")
for column, count in zero_counts.items():
    print(f"Column '{column}' has {count} rows with zero values.")

# Opcional: mostrar el diccionario completo de ceros
print("\nCounts of zero values per column:", zero_counts)
# Out:
# Columns with zero values and their counts:
# Column 'new_confirmed' has 61 rows with zero values.
# Column 'new_deceased' has 87 rows with zero values.
# Column 'cumulative_confirmed' has 57 rows with zero values.
# Column 'cumulative_deceased' has 81 rows with zero values.
# Column 'rainfall_mm' has 678 rows with zero values.
# Column 'new_recovered' has 848 rows with zero values.
# Column 'cumulative_recovered' has 15 rows with zero values.
#
# Counts of zero values per column: {'new_confirmed': 61, 'new_deceased': 87, 'cumulative_confirmed': 57, 'cumulative_deceased': 81, 'rainfall_mm': 678, 'new_recovered': 848, 'cumulative_recovered': 15}

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df_cl.describe()
# Out:
#        new_confirmed  new_deceased  cumulative_vaccine_doses_administered  \
# count         974.00        974.00                                 961.00
# mean         4426.58         62.06                            21853699.34
# std          5930.18        370.52                            22632949.80
# min             0.00          0.00                                   0.00
# 25%          1227.25         11.00                                   0.00
# 50%          2369.00         32.00                            15773547.00
# 75%          5515.00         71.00                            44495954.00
# max         38446.00      11447.00                            61953990.00
#
#        population  population_male  population_female  population_density  \
# count      974.00           974.00             974.00              974.00
# mean  17574003.00       8972014.00         8601989.00               25.71
# std          0.00             0.00               0.00                0.00
# min   17574003.00       8972014.00         8601989.00               25.71
# 25%   17574003.00       8972014.00         8601989.00               25.71
# 50%   17574003.00       8972014.00         8601989.00               25.71
# 75%   17574003.00       8972014.00         8601989.00               25.71
# max   17574003.00       8972014.00         8601989.00               25.71
#
#        human_development_index  population_age_00_09  population_age_10_19  \
# count                   974.00                974.00                974.00
# mean                      0.83            2428079.00            2493879.00
# std                       0.00                  0.00                  0.00
# min                       0.83            2428079.00            2493879.00
# 25%                       0.83            2428079.00            2493879.00
# 50%                       0.83            2428079.00            2493879.00
# 75%                       0.83            2428079.00            2493879.00
# max                       0.83            2428079.00            2493879.00
#
#        ...  average_temperature_celsius  relative_humidity  \
# count  ...                       974.00             974.00
# mean   ...                        15.37              62.67
# std    ...                         4.95               9.30
# min    ...                         4.09              33.53
# 25%    ...                        11.13              55.39
# 50%    ...                        15.34              62.80
# 75%    ...                        19.78              69.19
# max    ...                        26.17              89.07
#
#        population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# count                   974.00            974.00            974.00
# mean                6723516.00         709418.00          12027.00
# std                       0.00              0.00              0.00
# min                 6723516.00         709418.00          12027.00
# 25%                 6723516.00         709418.00          12027.00
# 50%                 6723516.00         709418.00          12027.00
# 75%                 6723516.00         709418.00          12027.00
# max                 6723516.00         709418.00          12027.00
#
#        life_expectancy  adult_male_mortality_rate  \
# count           974.00                     974.00
# mean             80.04                     107.67
# std               0.00                       0.00
# min              80.04                     107.67
# 25%              80.04                     107.67
# 50%              80.04                     107.67
# 75%              80.04                     107.67
# max              80.04                     107.67
#
#        adult_female_mortality_rate  pollution_mortality_rate  \
# count                       974.00                    974.00
# mean                         59.03                     25.30
# std                           0.00                      0.00
# min                          59.03                     25.30
# 25%                          59.03                     25.30
# 50%                          59.03                     25.30
# 75%                          59.03                     25.30
# max                          59.03                     25.30
#
#        comorbidity_mortality_rate
# count                      974.00
# mean                        12.40
# std                          0.00
# min                         12.40
# 25%                         12.40
# 50%                         12.40
# 75%                         12.40
# max                         12.40
#
# [8 rows x 37 columns]

# %%
#calcular columna vacunas administradas por dia
g=df_cl.cumulative_vaccine_doses_administered.tolist()
h=[0.0]
for i in range(1,len(g)):
    h.append(g[i]-g[i-1])
df_cl['vaccine_doses_administered_for_day']=h

df_cl.vaccine_doses_administered_for_day.max()
# Out:
# 430493.0

# %%
df_cl.drop(columns='cumulative_vaccine_doses_administered', inplace=True)

# %%
# Crear la columna del acumulado de vacunas diarias
df_cl['cumulative_vaccine_doses_administered'] = df_cl['vaccine_doses_administered_for_day'].cumsum()

col = list(df_cl.columns)
col.remove('cumulative_vaccine_doses_administered')
col.insert(7, 'cumulative_vaccine_doses_administered')
df_cl = df_cl[col]
df_cl
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6115461           CL  2020-01-01           CL        Chile           0.00
# 6115462           CL  2020-01-02           CL        Chile           0.00
# 6115463           CL  2020-01-03           CL        Chile           0.00
# 6115464           CL  2020-01-04           CL        Chile           0.00
# 6115465           CL  2020-01-05           CL        Chile           0.00
# ...              ...         ...          ...          ...            ...
# 6116430           CL  2022-08-27           CL        Chile        7455.00
# 6116431           CL  2022-08-28           CL        Chile        6657.00
# 6116432           CL  2022-08-29           CL        Chile        4659.00
# 6116433           CL  2022-08-30           CL        Chile        3348.00
# 6116434           CL  2022-08-31           CL        Chile        5676.00
#
#          new_deceased  population  cumulative_vaccine_doses_administered  \
# 6115461          0.00 17574003.00                                   0.00
# 6115462          0.00 17574003.00                                   0.00
# 6115463          0.00 17574003.00                                   0.00
# 6115464          0.00 17574003.00                                   0.00
# 6115465          0.00 17574003.00                                   0.00
# ...               ...         ...                                    ...
# 6116430         29.00 17574003.00                            61836654.00
# 6116431         30.00 17574003.00                            61837598.00
# 6116432         23.00 17574003.00                            61870447.00
# 6116433         10.00 17574003.00                            61902121.00
# 6116434          6.00 17574003.00                            61931427.00
#
#          population_male  population_female  ...  relative_humidity  \
# 6115461       8972014.00         8601989.00  ...              57.37
# 6115462       8972014.00         8601989.00  ...              62.00
# 6115463       8972014.00         8601989.00  ...              65.80
# 6115464       8972014.00         8601989.00  ...              65.11
# 6115465       8972014.00         8601989.00  ...              64.95
# ...                  ...                ...  ...                ...
# 6116430       8972014.00         8601989.00  ...              56.20
# 6116431       8972014.00         8601989.00  ...              43.79
# 6116432       8972014.00         8601989.00  ...              55.35
# 6116433       8972014.00         8601989.00  ...              63.18
# 6116434       8972014.00         8601989.00  ...              60.10
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6115461               6723516.00         709418.00          12027.00
# 6115462               6723516.00         709418.00          12027.00
# 6115463               6723516.00         709418.00          12027.00
# 6115464               6723516.00         709418.00          12027.00
# 6115465               6723516.00         709418.00          12027.00
# ...                          ...               ...               ...
# 6116430               6723516.00         709418.00          12027.00
# 6116431               6723516.00         709418.00          12027.00
# 6116432               6723516.00         709418.00          12027.00
# 6116433               6723516.00         709418.00          12027.00
# 6116434               6723516.00         709418.00          12027.00
#
#          life_expectancy  adult_male_mortality_rate  \
# 6115461            80.04                     107.67
# 6115462            80.04                     107.67
# 6115463            80.04                     107.67
# 6115464            80.04                     107.67
# 6115465            80.04                     107.67
# ...                  ...                        ...
# 6116430            80.04                     107.67
# 6116431            80.04                     107.67
# 6116432            80.04                     107.67
# 6116433            80.04                     107.67
# 6116434            80.04                     107.67
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6115461                        59.03                     25.30
# 6115462                        59.03                     25.30
# 6115463                        59.03                     25.30
# 6115464                        59.03                     25.30
# 6115465                        59.03                     25.30
# ...                              ...                       ...
# 6116430                        59.03                     25.30
# 6116431                        59.03                     25.30
# 6116432                        59.03                     25.30
# 6116433                        59.03                     25.30
# 6116434                        59.03                     25.30
#
#          comorbidity_mortality_rate  vaccine_doses_administered_for_day
# 6115461                       12.40                                0.00
# 6115462                       12.40                                0.00
# 6115463                       12.40                                0.00
# 6115464                       12.40                                0.00
# 6115465                       12.40                                0.00
# ...                             ...                                 ...
# 6116430                       12.40                             9156.00
# 6116431                       12.40                              944.00
# 6116432                       12.40                            32849.00
# 6116433                       12.40                            31674.00
# 6116434                       12.40                            29306.00
#
# [974 rows x 42 columns]

# %%
col = list(df_cl.columns)
col.remove('vaccine_doses_administered_for_day')
col.insert(6, 'vaccine_doses_administered_for_day')
df_cl = df_cl[col]
df_cl
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6115461           CL  2020-01-01           CL        Chile           0.00
# 6115462           CL  2020-01-02           CL        Chile           0.00
# 6115463           CL  2020-01-03           CL        Chile           0.00
# 6115464           CL  2020-01-04           CL        Chile           0.00
# 6115465           CL  2020-01-05           CL        Chile           0.00
# ...              ...         ...          ...          ...            ...
# 6116430           CL  2022-08-27           CL        Chile        7455.00
# 6116431           CL  2022-08-28           CL        Chile        6657.00
# 6116432           CL  2022-08-29           CL        Chile        4659.00
# 6116433           CL  2022-08-30           CL        Chile        3348.00
# 6116434           CL  2022-08-31           CL        Chile        5676.00
#
#          new_deceased  vaccine_doses_administered_for_day  population  \
# 6115461          0.00                                0.00 17574003.00
# 6115462          0.00                                0.00 17574003.00
# 6115463          0.00                                0.00 17574003.00
# 6115464          0.00                                0.00 17574003.00
# 6115465          0.00                                0.00 17574003.00
# ...               ...                                 ...         ...
# 6116430         29.00                             9156.00 17574003.00
# 6116431         30.00                              944.00 17574003.00
# 6116432         23.00                            32849.00 17574003.00
# 6116433         10.00                            31674.00 17574003.00
# 6116434          6.00                            29306.00 17574003.00
#
#          cumulative_vaccine_doses_administered  population_male  ...  \
# 6115461                                   0.00       8972014.00  ...
# 6115462                                   0.00       8972014.00  ...
# 6115463                                   0.00       8972014.00  ...
# 6115464                                   0.00       8972014.00  ...
# 6115465                                   0.00       8972014.00  ...
# ...                                        ...              ...  ...
# 6116430                            61836654.00       8972014.00  ...
# 6116431                            61837598.00       8972014.00  ...
# 6116432                            61870447.00       8972014.00  ...
# 6116433                            61902121.00       8972014.00  ...
# 6116434                            61931427.00       8972014.00  ...
#
#          average_temperature_celsius  relative_humidity  \
# 6115461                        20.80              57.37
# 6115462                        19.89              62.00
# 6115463                        20.14              65.80
# 6115464                        21.08              65.11
# 6115465                        19.46              64.95
# ...                              ...                ...
# 6116430                        12.85              56.20
# 6116431                        12.08              43.79
# 6116432                        11.44              55.35
# 6116433                        11.38              63.18
# 6116434                        12.02              60.10
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6115461               6723516.00         709418.00          12027.00
# 6115462               6723516.00         709418.00          12027.00
# 6115463               6723516.00         709418.00          12027.00
# 6115464               6723516.00         709418.00          12027.00
# 6115465               6723516.00         709418.00          12027.00
# ...                          ...               ...               ...
# 6116430               6723516.00         709418.00          12027.00
# 6116431               6723516.00         709418.00          12027.00
# 6116432               6723516.00         709418.00          12027.00
# 6116433               6723516.00         709418.00          12027.00
# 6116434               6723516.00         709418.00          12027.00
#
#          life_expectancy  adult_male_mortality_rate  \
# 6115461            80.04                     107.67
# 6115462            80.04                     107.67
# 6115463            80.04                     107.67
# 6115464            80.04                     107.67
# 6115465            80.04                     107.67
# ...                  ...                        ...
# 6116430            80.04                     107.67
# 6116431            80.04                     107.67
# 6116432            80.04                     107.67
# 6116433            80.04                     107.67
# 6116434            80.04                     107.67
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6115461                        59.03                     25.30
# 6115462                        59.03                     25.30
# 6115463                        59.03                     25.30
# 6115464                        59.03                     25.30
# 6115465                        59.03                     25.30
# ...                              ...                       ...
# 6116430                        59.03                     25.30
# 6116431                        59.03                     25.30
# 6116432                        59.03                     25.30
# 6116433                        59.03                     25.30
# 6116434                        59.03                     25.30
#
#          comorbidity_mortality_rate
# 6115461                       12.40
# 6115462                       12.40
# 6115463                       12.40
# 6115464                       12.40
# 6115465                       12.40
# ...                             ...
# 6116430                       12.40
# 6116431                       12.40
# 6116432                       12.40
# 6116433                       12.40
# 6116434                       12.40
#
# [974 rows x 42 columns]

# %%
df_cl.describe()
# Out:
#        new_confirmed  new_deceased  vaccine_doses_administered_for_day  \
# count         974.00        974.00                              954.00
# mean         4426.58         62.06                            64917.64
# std          5930.18        370.52                            87866.45
# min             0.00          0.00                            -8648.00
# 25%          1227.25         11.00                                0.00
# 50%          2369.00         32.00                             5865.50
# 75%          5515.00         71.00                           125030.25
# max         38446.00      11447.00                           430493.00
#
#        population  cumulative_vaccine_doses_administered  population_male  \
# count      974.00                                 954.00           974.00
# mean  17574003.00                            21999941.64       8972014.00
# std          0.00                            22629778.07             0.00
# min   17574003.00                                   0.00       8972014.00
# 25%   17574003.00                                   0.00       8972014.00
# 50%   17574003.00                            16211028.50       8972014.00
# 75%   17574003.00                            44752642.50       8972014.00
# max   17574003.00                            61931427.00       8972014.00
#
#        population_female  population_density  human_development_index  \
# count             974.00              974.00                   974.00
# mean          8601989.00               25.71                     0.83
# std                 0.00                0.00                     0.00
# min           8601989.00               25.71                     0.83
# 25%           8601989.00               25.71                     0.83
# 50%           8601989.00               25.71                     0.83
# 75%           8601989.00               25.71                     0.83
# max           8601989.00               25.71                     0.83
#
#        population_age_00_09  ...  average_temperature_celsius  \
# count                974.00  ...                       974.00
# mean             2428079.00  ...                        15.37
# std                    0.00  ...                         4.95
# min              2428079.00  ...                         4.09
# 25%              2428079.00  ...                        11.13
# 50%              2428079.00  ...                        15.34
# 75%              2428079.00  ...                        19.78
# max              2428079.00  ...                        26.17
#
#        relative_humidity  population_largest_city  area_rural_sq_km  \
# count             974.00                   974.00            974.00
# mean               62.67               6723516.00         709418.00
# std                 9.30                     0.00              0.00
# min                33.53               6723516.00         709418.00
# 25%                55.39               6723516.00         709418.00
# 50%                62.80               6723516.00         709418.00
# 75%                69.19               6723516.00         709418.00
# max                89.07               6723516.00         709418.00
#
#        area_urban_sq_km  life_expectancy  adult_male_mortality_rate  \
# count            974.00           974.00                     974.00
# mean           12027.00            80.04                     107.67
# std                0.00             0.00                       0.00
# min            12027.00            80.04                     107.67
# 25%            12027.00            80.04                     107.67
# 50%            12027.00            80.04                     107.67
# 75%            12027.00            80.04                     107.67
# max            12027.00            80.04                     107.67
#
#        adult_female_mortality_rate  pollution_mortality_rate  \
# count                       974.00                    974.00
# mean                         59.03                     25.30
# std                           0.00                      0.00
# min                          59.03                     25.30
# 25%                          59.03                     25.30
# 50%                          59.03                     25.30
# 75%                          59.03                     25.30
# max                          59.03                     25.30
#
#        comorbidity_mortality_rate
# count                      974.00
# mean                        12.40
# std                          0.00
# min                         12.40
# 25%                         12.40
# 50%                         12.40
# 75%                         12.40
# max                         12.40
#
# [8 rows x 38 columns]

# %%
# Calcular media y desvio estandar
media = df_cl['vaccine_doses_administered_for_day'].mean()
desvio_estandar = df_cl['vaccine_doses_administered_for_day'].std()

# Definir los límites para considerar outliers
lower_bound = media - 3 * desvio_estandar
upper_bound = media + 3 * desvio_estandar

# Verificar si lower_bound es menor a 0
if lower_bound < 0:
    lower_bound = 0

# Filtrar el DataFrame para ver los outliers
df_cl[(df_cl['vaccine_doses_administered_for_day'] < lower_bound) | (df_cl['vaccine_doses_administered_for_day'] > upper_bound)]
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6115823           CL  2020-12-28           CL        Chile        1923.00
# 6115893           CL  2021-03-08           CL        Chile        4733.00
# 6115894           CL  2021-03-09           CL        Chile        3528.00
# 6115895           CL  2021-03-10           CL        Chile        3958.00
# 6115896           CL  2021-03-11           CL        Chile        5566.00
# 6115897           CL  2021-03-12           CL        Chile        5983.00
# 6115900           CL  2021-03-15           CL        Chile        5117.00
# 6115901           CL  2021-03-16           CL        Chile        4591.00
# 6115902           CL  2021-03-17           CL        Chile        4395.00
# 6115903           CL  2021-03-18           CL        Chile        6249.00
#
#          new_deceased  vaccine_doses_administered_for_day  population  \
# 6115823          0.00                            -8648.00 17574003.00
# 6115893         86.00                           350820.00 17574003.00
# 6115894         19.00                           376708.00 17574003.00
# 6115895         24.00                           401527.00 17574003.00
# 6115896        156.00                           417231.00 17574003.00
# 6115897         89.00                           374530.00 17574003.00
# 6115900         98.00                           430493.00 17574003.00
# 6115901         17.00                           410432.00 17574003.00
# 6115902         27.00                           367465.00 17574003.00
# 6115903        172.00                           335162.00 17574003.00
#
#          cumulative_vaccine_doses_administered  population_male  ...  \
# 6115823                                   0.00       8972014.00  ...
# 6115893                             4972997.00       8972014.00  ...
# 6115894                             5349705.00       8972014.00  ...
# 6115895                             5751232.00       8972014.00  ...
# 6115896                             6168463.00       8972014.00  ...
# 6115897                             6542993.00       8972014.00  ...
# 6115900                             7030563.00       8972014.00  ...
# 6115901                             7440995.00       8972014.00  ...
# 6115902                             7808460.00       8972014.00  ...
# 6115903                             8143622.00       8972014.00  ...
#
#          average_temperature_celsius  relative_humidity  \
# 6115823                        20.57              65.36
# 6115893                        22.78              54.36
# 6115894                        21.44              55.64
# 6115895                        21.88              60.39
# 6115896                        21.43              58.00
# 6115897                        20.75              61.85
# 6115900                        18.41              77.43
# 6115901                        18.72              66.45
# 6115902                        17.09              71.05
# 6115903                        14.02              80.95
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6115823               6723516.00         709418.00          12027.00
# 6115893               6723516.00         709418.00          12027.00
# 6115894               6723516.00         709418.00          12027.00
# 6115895               6723516.00         709418.00          12027.00
# 6115896               6723516.00         709418.00          12027.00
# 6115897               6723516.00         709418.00          12027.00
# 6115900               6723516.00         709418.00          12027.00
# 6115901               6723516.00         709418.00          12027.00
# 6115902               6723516.00         709418.00          12027.00
# 6115903               6723516.00         709418.00          12027.00
#
#          life_expectancy  adult_male_mortality_rate  \
# 6115823            80.04                     107.67
# 6115893            80.04                     107.67
# 6115894            80.04                     107.67
# 6115895            80.04                     107.67
# 6115896            80.04                     107.67
# 6115897            80.04                     107.67
# 6115900            80.04                     107.67
# 6115901            80.04                     107.67
# 6115902            80.04                     107.67
# 6115903            80.04                     107.67
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6115823                        59.03                     25.30
# 6115893                        59.03                     25.30
# 6115894                        59.03                     25.30
# 6115895                        59.03                     25.30
# 6115896                        59.03                     25.30
# 6115897                        59.03                     25.30
# 6115900                        59.03                     25.30
# 6115901                        59.03                     25.30
# 6115902                        59.03                     25.30
# 6115903                        59.03                     25.30
#
#          comorbidity_mortality_rate
# 6115823                       12.40
# 6115893                       12.40
# 6115894                       12.40
# 6115895                       12.40
# 6115896                       12.40
# 6115897                       12.40
# 6115900                       12.40
# 6115901                       12.40
# 6115902                       12.40
# 6115903                       12.40
#
# [10 rows x 42 columns]

# %%
# Filtrar el DataFrame para mantener solo los valores dentro de los límites
df_filtered= df_cl[(df_cl['vaccine_doses_administered_for_day'] >= lower_bound) & (df_cl['vaccine_doses_administered_for_day'] <= upper_bound)]

# %%
# Ajustar la escala del eje Y para mostrar números completos
plt.ticklabel_format(style='plain', axis='y')

# Boxplot con matplotlib
plt.boxplot(df_filtered['vaccine_doses_administered_for_day'])
plt.title('Boxplot de vaccine_doses_administered_for_day')
plt.show()

# Filtrar los datos para excluir los valores 0
df_filtered_non_zero = df_filtered[df_filtered['vaccine_doses_administered_for_day'] > 0]

# Histograma con matplotlib
plt.hist(df_filtered_non_zero['vaccine_doses_administered_for_day'], bins=10)  # el número de bins se puede ajustar a preferencia
plt.title('Histograma de vaccine_doses_administered_for_day (sin valores 0)')
plt.show()

# %%
avg_vaccine = round(df_cl['vaccine_doses_administered_for_day'].mean(), 0)

df_prueba = df_cl.copy()  # Crear una copia del DataFrame original

# Reemplazar los valores por encima del valor máximo o por debajo del valor mínimo con el promedio
df_prueba['vaccine_doses_administered_for_day'] = df_prueba['vaccine_doses_administered_for_day'].apply(
    lambda x: avg_vaccine if x > upper_bound or x < lower_bound else x
)

# %%
# Calcular media y desvio estandar
media = df_cl['new_deceased'].mean()
desvio_estandar = df_cl['new_deceased'].std()

# Definir los límites para considerar outliers
lower_bound = media - 3 * desvio_estandar
upper_bound = media + 3 * desvio_estandar

# Verificar si lower_bound es menor a 0
if lower_bound < 0:
    lower_bound = 0

# Filtrar el DataFrame para ver los outliers
df_cl[(df_cl['new_deceased'] < lower_bound) | (df_cl['new_deceased'] > upper_bound)]
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6116271           CL  2022-03-21           CL        Chile        7555.00
#
#          new_deceased  vaccine_doses_administered_for_day  population  \
# 6116271      11447.00                            84207.00 17574003.00
#
#          cumulative_vaccine_doses_administered  population_male  ...  \
# 6116271                            50230967.00       8972014.00  ...
#
#          average_temperature_celsius  relative_humidity  \
# 6116271                        17.24              57.67
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6116271               6723516.00         709418.00          12027.00
#
#          life_expectancy  adult_male_mortality_rate  \
# 6116271            80.04                     107.67
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6116271                        59.03                     25.30
#
#          comorbidity_mortality_rate
# 6116271                       12.40
#
# [1 rows x 42 columns]

# %%
df_cl[(df_cl['date'] < "2022-03-25") & (df_cl['date'] > "2022-03-17")]
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6116268           CL  2022-03-18           CL        Chile       14525.00
# 6116269           CL  2022-03-19           CL        Chile       12357.00
# 6116270           CL  2022-03-20           CL        Chile       10472.00
# 6116271           CL  2022-03-21           CL        Chile        7555.00
# 6116272           CL  2022-03-22           CL        Chile        5045.00
# 6116273           CL  2022-03-23           CL        Chile        8025.00
# 6116274           CL  2022-03-24           CL        Chile        9414.00
#
#          new_deceased  vaccine_doses_administered_for_day  population  \
# 6116268         93.00                            88154.00 17574003.00
# 6116269        101.00                            12685.00 17574003.00
# 6116270         78.00                              581.00 17574003.00
# 6116271      11447.00                            84207.00 17574003.00
# 6116272         11.00                            81123.00 17574003.00
# 6116273         16.00                            73680.00 17574003.00
# 6116274        155.00                            67211.00 17574003.00
#
#          cumulative_vaccine_doses_administered  population_male  ...  \
# 6116268                            50133494.00       8972014.00  ...
# 6116269                            50146179.00       8972014.00  ...
# 6116270                            50146760.00       8972014.00  ...
# 6116271                            50230967.00       8972014.00  ...
# 6116272                            50312090.00       8972014.00  ...
# 6116273                            50385770.00       8972014.00  ...
# 6116274                            50452981.00       8972014.00  ...
#
#          average_temperature_celsius  relative_humidity  \
# 6116268                        18.53              54.66
# 6116269                        18.67              51.46
# 6116270                        18.73              53.72
# 6116271                        17.24              57.67
# 6116272                        18.70              57.97
# 6116273                        18.04              58.15
# 6116274                        15.47              44.84
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6116268               6723516.00         709418.00          12027.00
# 6116269               6723516.00         709418.00          12027.00
# 6116270               6723516.00         709418.00          12027.00
# 6116271               6723516.00         709418.00          12027.00
# 6116272               6723516.00         709418.00          12027.00
# 6116273               6723516.00         709418.00          12027.00
# 6116274               6723516.00         709418.00          12027.00
#
#          life_expectancy  adult_male_mortality_rate  \
# 6116268            80.04                     107.67
# 6116269            80.04                     107.67
# 6116270            80.04                     107.67
# 6116271            80.04                     107.67
# 6116272            80.04                     107.67
# 6116273            80.04                     107.67
# 6116274            80.04                     107.67
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6116268                        59.03                     25.30
# 6116269                        59.03                     25.30
# 6116270                        59.03                     25.30
# 6116271                        59.03                     25.30
# 6116272                        59.03                     25.30
# 6116273                        59.03                     25.30
# 6116274                        59.03                     25.30
#
#          comorbidity_mortality_rate
# 6116268                       12.40
# 6116269                       12.40
# 6116270                       12.40
# 6116271                       12.40
# 6116272                       12.40
# 6116273                       12.40
# 6116274                       12.40
#
# [7 rows x 42 columns]

# %%
avg_deceased = round(df_cl['new_deceased'].mean(), 0)

df_prueba = df_cl.copy()  # Crear una copia del DataFrame original

# Reemplazar los valores por encima del valor máximo o por debajo del valor mínimo con el promedio
df_prueba['new_deceased'] = df_prueba['new_deceased'].apply(
    lambda x: avg_deceased if x > upper_bound or x < lower_bound else x
)

# %%
df_prueba.to_csv('../../data/processed/covid19_Chile.csv', index=False)

# %%
df_prueba.describe()
# Out:
#        new_confirmed  new_deceased  vaccine_doses_administered_for_day  \
# count         974.00        974.00                              954.00
# mean         4426.58         50.38                            64917.64
# std          5930.18         62.75                            87866.45
# min             0.00          0.00                            -8648.00
# 25%          1227.25         11.00                                0.00
# 50%          2369.00         32.00                             5865.50
# 75%          5515.00         70.75                           125030.25
# max         38446.00       1057.00                           430493.00
#
#        population  cumulative_vaccine_doses_administered  population_male  \
# count      974.00                                 954.00           974.00
# mean  17574003.00                            21999941.64       8972014.00
# std          0.00                            22629778.07             0.00
# min   17574003.00                                   0.00       8972014.00
# 25%   17574003.00                                   0.00       8972014.00
# 50%   17574003.00                            16211028.50       8972014.00
# 75%   17574003.00                            44752642.50       8972014.00
# max   17574003.00                            61931427.00       8972014.00
#
#        population_female  population_density  human_development_index  \
# count             974.00              974.00                   974.00
# mean          8601989.00               25.71                     0.83
# std                 0.00                0.00                     0.00
# min           8601989.00               25.71                     0.83
# 25%           8601989.00               25.71                     0.83
# 50%           8601989.00               25.71                     0.83
# 75%           8601989.00               25.71                     0.83
# max           8601989.00               25.71                     0.83
#
#        population_age_00_09  ...  average_temperature_celsius  \
# count                974.00  ...                       974.00
# mean             2428079.00  ...                        15.37
# std                    0.00  ...                         4.95
# min              2428079.00  ...                         4.09
# 25%              2428079.00  ...                        11.13
# 50%              2428079.00  ...                        15.34
# 75%              2428079.00  ...                        19.78
# max              2428079.00  ...                        26.17
#
#        relative_humidity  population_largest_city  area_rural_sq_km  \
# count             974.00                   974.00            974.00
# mean               62.67               6723516.00         709418.00
# std                 9.30                     0.00              0.00
# min                33.53               6723516.00         709418.00
# 25%                55.39               6723516.00         709418.00
# 50%                62.80               6723516.00         709418.00
# 75%                69.19               6723516.00         709418.00
# max                89.07               6723516.00         709418.00
#
#        area_urban_sq_km  life_expectancy  adult_male_mortality_rate  \
# count            974.00           974.00                     974.00
# mean           12027.00            80.04                     107.67
# std                0.00             0.00                       0.00
# min            12027.00            80.04                     107.67
# 25%            12027.00            80.04                     107.67
# 50%            12027.00            80.04                     107.67
# 75%            12027.00            80.04                     107.67
# max            12027.00            80.04                     107.67
#
#        adult_female_mortality_rate  pollution_mortality_rate  \
# count                       974.00                    974.00
# mean                         59.03                     25.30
# std                           0.00                      0.00
# min                          59.03                     25.30
# 25%                          59.03                     25.30
# 50%                          59.03                     25.30
# 75%                          59.03                     25.30
# max                          59.03                     25.30
#
#        comorbidity_mortality_rate
# count                      974.00
# mean                        12.40
# std                          0.00
# min                         12.40
# 25%                         12.40
# 50%                         12.40
# 75%                         12.40
# max                         12.40
#
# [8 rows x 38 columns]
