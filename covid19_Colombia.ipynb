# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Desktop\simulacion_3\\Notebooks\data_latinoamerica.csv')

# %%
df = df[df['location_key'] == 'CO']

# %%
df.head(20)
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6475194           CO  2020-01-01           CO     Colombia            0.0
# 6475195           CO  2020-01-02           CO     Colombia            0.0
# 6475196           CO  2020-01-03           CO     Colombia            0.0
# 6475197           CO  2020-01-04           CO     Colombia            0.0
# 6475198           CO  2020-01-05           CO     Colombia            0.0
# 6475199           CO  2020-01-06           CO     Colombia            0.0
# 6475200           CO  2020-01-07           CO     Colombia            0.0
# 6475201           CO  2020-01-08           CO     Colombia            0.0
# 6475202           CO  2020-01-09           CO     Colombia            0.0
# 6475203           CO  2020-01-10           CO     Colombia            0.0
# 6475204           CO  2020-01-11           CO     Colombia            0.0
# 6475205           CO  2020-01-12           CO     Colombia            0.0
# 6475206           CO  2020-01-13           CO     Colombia            0.0
# 6475207           CO  2020-01-14           CO     Colombia            0.0
# 6475208           CO  2020-01-15           CO     Colombia            0.0
# 6475209           CO  2020-01-16           CO     Colombia            0.0
# 6475210           CO  2020-01-17           CO     Colombia            0.0
# 6475211           CO  2020-01-18           CO     Colombia            0.0
# 6475212           CO  2020-01-19           CO     Colombia            0.0
# 6475213           CO  2020-01-20           CO     Colombia            0.0
#
#          new_deceased  cumulative_confirmed  cumulative_deceased  \
# 6475194           0.0                   0.0                  0.0
# 6475195           0.0                   0.0                  0.0
# 6475196           0.0                   0.0                  0.0
# 6475197           0.0                   0.0                  0.0
# 6475198           0.0                   0.0                  0.0
# 6475199           0.0                   0.0                  0.0
# 6475200           0.0                   0.0                  0.0
# 6475201           0.0                   0.0                  0.0
# 6475202           0.0                   0.0                  0.0
# 6475203           0.0                   0.0                  0.0
# 6475204           0.0                   0.0                  0.0
# 6475205           0.0                   0.0                  0.0
# 6475206           0.0                   0.0                  0.0
# 6475207           0.0                   0.0                  0.0
# 6475208           0.0                   0.0                  0.0
# 6475209           0.0                   0.0                  0.0
# 6475210           0.0                   0.0                  0.0
# 6475211           0.0                   0.0                  0.0
# 6475212           0.0                   0.0                  0.0
# 6475213           0.0                   0.0                  0.0
#
#          cumulative_vaccine_doses_administered  population  ...  \
# 6475194                                    NaN  50882884.0  ...
# 6475195                                    NaN  50882884.0  ...
# 6475196                                    NaN  50882884.0  ...
# 6475197                                    NaN  50882884.0  ...
# 6475198                                    NaN  50882884.0  ...
# 6475199                                    NaN  50882884.0  ...
# 6475200                                    NaN  50882884.0  ...
# 6475201                                    NaN  50882884.0  ...
# 6475202                                    NaN  50882884.0  ...
# 6475203                                    NaN  50882884.0  ...
# 6475204                                    NaN  50882884.0  ...
# 6475205                                    NaN  50882884.0  ...
# 6475206                                    NaN  50882884.0  ...
# 6475207                                    NaN  50882884.0  ...
# 6475208                                    NaN  50882884.0  ...
# 6475209                                    NaN  50882884.0  ...
# 6475210                                    NaN  50882884.0  ...
# 6475211                                    NaN  50882884.0  ...
# 6475212                                    NaN  50882884.0  ...
# 6475213                                    NaN  50882884.0  ...
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6475194               10779376.0         1090598.0           36132.0
# 6475195               10779376.0         1090598.0           36132.0
# 6475196               10779376.0         1090598.0           36132.0
# 6475197               10779376.0         1090598.0           36132.0
# 6475198               10779376.0         1090598.0           36132.0
# 6475199               10779376.0         1090598.0           36132.0
# 6475200               10779376.0         1090598.0           36132.0
# 6475201               10779376.0         1090598.0           36132.0
# 6475202               10779376.0         1090598.0           36132.0
# 6475203               10779376.0         1090598.0           36132.0
# 6475204               10779376.0         1090598.0           36132.0
# 6475205               10779376.0         1090598.0           36132.0
# 6475206               10779376.0         1090598.0           36132.0
# 6475207               10779376.0         1090598.0           36132.0
# 6475208               10779376.0         1090598.0           36132.0
# 6475209               10779376.0         1090598.0           36132.0
# 6475210               10779376.0         1090598.0           36132.0
# 6475211               10779376.0         1090598.0           36132.0
# 6475212               10779376.0         1090598.0           36132.0
# 6475213               10779376.0         1090598.0           36132.0
#
#          life_expectancy  adult_male_mortality_rate  \
# 6475194           77.109                    151.616
# 6475195           77.109                    151.616
# 6475196           77.109                    151.616
# 6475197           77.109                    151.616
# 6475198           77.109                    151.616
# 6475199           77.109                    151.616
# 6475200           77.109                    151.616
# 6475201           77.109                    151.616
# 6475202           77.109                    151.616
# 6475203           77.109                    151.616
# 6475204           77.109                    151.616
# 6475205           77.109                    151.616
# 6475206           77.109                    151.616
# 6475207           77.109                    151.616
# 6475208           77.109                    151.616
# 6475209           77.109                    151.616
# 6475210           77.109                    151.616
# 6475211           77.109                    151.616
# 6475212           77.109                    151.616
# 6475213           77.109                    151.616
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6475194                       77.999                      37.0
# 6475195                       77.999                      37.0
# 6475196                       77.999                      37.0
# 6475197                       77.999                      37.0
# 6475198                       77.999                      37.0
# 6475199                       77.999                      37.0
# 6475200                       77.999                      37.0
# 6475201                       77.999                      37.0
# 6475202                       77.999                      37.0
# 6475203                       77.999                      37.0
# 6475204                       77.999                      37.0
# 6475205                       77.999                      37.0
# 6475206                       77.999                      37.0
# 6475207                       77.999                      37.0
# 6475208                       77.999                      37.0
# 6475209                       77.999                      37.0
# 6475210                       77.999                      37.0
# 6475211                       77.999                      37.0
# 6475212                       77.999                      37.0
# 6475213                       77.999                      37.0
#
#          comorbidity_mortality_rate  new_recovered  cumulative_recovered
# 6475194                        15.8            NaN                   NaN
# 6475195                        15.8            NaN                   NaN
# 6475196                        15.8            NaN                   NaN
# 6475197                        15.8            NaN                   NaN
# 6475198                        15.8            NaN                   NaN
# 6475199                        15.8            NaN                   NaN
# 6475200                        15.8            NaN                   NaN
# 6475201                        15.8            NaN                   NaN
# 6475202                        15.8            NaN                   NaN
# 6475203                        15.8            NaN                   NaN
# 6475204                        15.8            NaN                   NaN
# 6475205                        15.8            NaN                   NaN
# 6475206                        15.8            NaN                   NaN
# 6475207                        15.8            NaN                   NaN
# 6475208                        15.8            NaN                   NaN
# 6475209                        15.8            NaN                   NaN
# 6475210                        15.8            NaN                   NaN
# 6475211                        15.8            NaN                   NaN
# 6475212                        15.8            NaN                   NaN
# 6475213                        15.8            NaN                   NaN
#
# [20 rows x 50 columns]

# %%
import matplotlib.pyplot as plt # type: ignore
import seaborn as sns # type: ignore
# Filtrar los datos para los primeros tres meses a partir del 6 de marzo de 2020
start_date = '2020-03-06'
end_date = '2020-03-13'
mask = (df['date'] >= start_date) & (df['date'] <= end_date)
filtered_df = df.loc[mask]

# Crear el gráfico de series temporales
plt.figure(figsize=(14, 7))
sns.lineplot(data=filtered_df, x='date', y='cumulative_confirmed', label='Cumulative Confirmed')
sns.lineplot(data=filtered_df, x='date', y='cumulative_deceased', label='Cumulative Deceased')
plt.title('Time Series of Cumulative Confirmed and Deceased Cases (First 3 Months from 2020-03-06)')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
filtered_df
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6475259           CO  2020-03-06           CO     Colombia            1.0
# 6475260           CO  2020-03-07           CO     Colombia            0.0
# 6475261           CO  2020-03-08           CO     Colombia            0.0
# 6475262           CO  2020-03-09           CO     Colombia            2.0
# 6475263           CO  2020-03-10           CO     Colombia            0.0
# 6475264           CO  2020-03-11           CO     Colombia            6.0
# 6475265           CO  2020-03-12           CO     Colombia            4.0
# 6475266           CO  2020-03-13           CO     Colombia            5.0
#
#          new_deceased  cumulative_confirmed  cumulative_deceased  \
# 6475259           0.0                   1.0                  0.0
# 6475260           1.0                   1.0                  1.0
# 6475261           0.0                   1.0                  0.0
# 6475262           0.0                   3.0                  1.0
# 6475263           1.0                   3.0                  2.0
# 6475264           1.0                   9.0                  3.0
# 6475265           0.0                  13.0                  3.0
# 6475266           0.0                  18.0                  3.0
#
#          cumulative_vaccine_doses_administered  population  ...  \
# 6475259                                    NaN  50882884.0  ...
# 6475260                                    NaN  50882884.0  ...
# 6475261                                    NaN  50882884.0  ...
# 6475262                                    NaN  50882884.0  ...
# 6475263                                    NaN  50882884.0  ...
# 6475264                                    NaN  50882884.0  ...
# 6475265                                    NaN  50882884.0  ...
# 6475266                                    NaN  50882884.0  ...
#
#          population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# 6475259               10779376.0         1090598.0           36132.0
# 6475260               10779376.0         1090598.0           36132.0
# 6475261               10779376.0         1090598.0           36132.0
# 6475262               10779376.0         1090598.0           36132.0
# 6475263               10779376.0         1090598.0           36132.0
# 6475264               10779376.0         1090598.0           36132.0
# 6475265               10779376.0         1090598.0           36132.0
# 6475266               10779376.0         1090598.0           36132.0
#
#          life_expectancy  adult_male_mortality_rate  \
# 6475259           77.109                    151.616
# 6475260           77.109                    151.616
# 6475261           77.109                    151.616
# 6475262           77.109                    151.616
# 6475263           77.109                    151.616
# 6475264           77.109                    151.616
# 6475265           77.109                    151.616
# 6475266           77.109                    151.616
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6475259                       77.999                      37.0
# 6475260                       77.999                      37.0
# 6475261                       77.999                      37.0
# 6475262                       77.999                      37.0
# 6475263                       77.999                      37.0
# 6475264                       77.999                      37.0
# 6475265                       77.999                      37.0
# 6475266                       77.999                      37.0
#
#          comorbidity_mortality_rate  new_recovered  cumulative_recovered
# 6475259                        15.8            0.0                   0.0
# 6475260                        15.8            0.0                   0.0
# 6475261                        15.8            NaN                   NaN
# 6475262                        15.8            0.0                   0.0
# 6475263                        15.8            0.0                   0.0
# 6475264                        15.8            0.0                   0.0
# 6475265                        15.8            0.0                   0.0
# 6475266                        15.8            1.0                   1.0
#
# [8 rows x 50 columns]

# %%
# Identificar las columnas que contienen valores 0
columns_with_zeros = df.columns[(df == 0).any()]

# Mostrar las columnas y las filas con valores 0
for column in columns_with_zeros:
    zero_rows = df[df[column] == 0]
    print(f"Column '{column}' has zero values in the following rows:")
    print(zero_rows)

# Alternativamente, para ver solo las columnas que tienen valores 0
print("Columns with zero values:", columns_with_zeros.tolist())
# Out:
# Column 'new_confirmed' has zero values in the following rows:
#         location_key        date country_code country_name  new_confirmed  \
# 6475194           CO  2020-01-01           CO     Colombia            0.0
# 6475195           CO  2020-01-02           CO     Colombia            0.0
# 6475196           CO  2020-01-03           CO     Colombia            0.0
# 6475197           CO  2020-01-04           CO     Colombia            0.0
# 6475198           CO  2020-01-05           CO     Colombia            0.0
# Columns with zero values: ['new_confirmed', 'new_deceased', 'cumulative_confirmed', 'cumulative_deceased', 'rainfall_mm', 'new_recovered', 'cumulative_recovered']

# %% [markdown]
# ### Contar cuantos valores Nulos tiene cada columna

# %%
# Contar cuántas filas contienen valores nulos en cada columna
null_counts = df.isnull().sum()

# Filtrar solo las columnas que tienen valores nulos
columns_with_nulls = null_counts[null_counts > 0]

# Mostrar el recuento de filas con valores nulos por columna
print("Columns with null values and their counts:")
print(columns_with_nulls)
# Out:
# Columns with null values and their counts:
# new_confirmed                              4
# new_deceased                               4
# cumulative_confirmed                       4
# cumulative_deceased                        4
# cumulative_vaccine_doses_administered    657
# average_temperature_celsius                7
# minimum_temperature_celsius                7
# maximum_temperature_celsius                7
# rainfall_mm                               94
# relative_humidity                          7
# new_recovered                            303
# cumulative_recovered                     303
# dtype: int64

# %% [markdown]
# ### Contar cuantos 0 tiene cada columna

# %%
# Contar cuántas filas contienen valores 0 en cada columna
columns_with_zeros = df.columns[(df == 0).any()]

# Crear un diccionario para almacenar el recuento de filas con valores 0
zero_counts = {column: (df[column] == 0).sum() for column in columns_with_zeros}

# Mostrar el recuento de filas con valores 0 por columna
print("\nColumns with zero values and their counts:")
for column, count in zero_counts.items():
    print(f"Column '{column}' has {count} rows with zero values.")

# Opcional: mostrar el diccionario completo de ceros
print("\nCounts of zero values per column:", zero_counts)
# Out:
# Columns with zero values and their counts:
# Column 'new_confirmed' has 185 rows with zero values.
# Column 'new_deceased' has 193 rows with zero values.
# Column 'cumulative_confirmed' has 65 rows with zero values.
# Column 'cumulative_deceased' has 67 rows with zero values.
# Column 'rainfall_mm' has 413 rows with zero values.
# Column 'new_recovered' has 8 rows with zero values.
# Column 'cumulative_recovered' has 6 rows with zero values.
#
# Counts of zero values per column: {'new_confirmed': 185, 'new_deceased': 193, 'cumulative_confirmed': 65, 'cumulative_deceased': 67, 'rainfall_mm': 413, 'new_recovered': 8, 'cumulative_recovered': 6}

# %% [markdown]
# # Transformacion de DF

# %% [markdown]
# #### Realizo un filtrado debido que anterior y posterior a estas fechas hay valores nulos y/o datos errones

# %%
# Definir el rango de fechas
start_date = '2020-03-06'
end_date = '2022-08-31'

# Filtrar el DataFrame para mantener las filas dentro del rango de fechas
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# %% [markdown]
# #### Elimino estas columnas por:
# #### las 2 primeras columnas tienen valores errones
# #### la 3ra columna tiene muchos valores en 0
# #### la 4 y 5ta columna tienen puros valores nulos
# #### la 6 y 7ma columna no concuerdan con el de poblacion
# #### Prefiero trabajar con el promedio de la temperatura del dia

# %%
columns_to_drop = [
    'cumulative_confirmed', 
    'cumulative_deceased', 
    'rainfall_mm', 
    'new_recovered',
    'cumulative_recovered',
    'population_rural',
    'population_urban', 
    'minimum_temperature_celsius', 
    'maximum_temperature_celsius'
]

# Eliminar las columnas
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.head()
# Out:
#         location_key        date country_code country_name  new_confirmed  \
# 6475259           CO  2020-03-06           CO     Colombia            1.0
# 6475260           CO  2020-03-07           CO     Colombia            0.0
# 6475261           CO  2020-03-08           CO     Colombia            0.0
# 6475262           CO  2020-03-09           CO     Colombia            2.0
# 6475263           CO  2020-03-10           CO     Colombia            0.0
#
#          new_deceased  cumulative_vaccine_doses_administered  population  \
# 6475259           0.0                                    NaN  50882884.0
# 6475260           1.0                                    NaN  50882884.0
# 6475261           0.0                                    NaN  50882884.0
# 6475262           0.0                                    NaN  50882884.0
# 6475263           1.0                                    NaN  50882884.0
#
#          population_male  population_female  ...  average_temperature_celsius  \
# 6475259       24984564.0         25898320.0  ...                    24.574074
# 6475260       24984564.0         25898320.0  ...                    23.722222
# 6475261       24984564.0         25898320.0  ...                    23.620370
# 6475262       24984564.0         25898320.0  ...                    23.407407
# 6475263       24984564.0         25898320.0  ...                    24.018519
#
#          relative_humidity  population_largest_city  area_rural_sq_km  \
# 6475259          60.939466               10779376.0         1090598.0
# 6475260          69.278718               10779376.0         1090598.0
# 6475261          70.720435               10779376.0         1090598.0
# 6475262          71.730307               10779376.0         1090598.0
# 6475263          68.912002               10779376.0         1090598.0
#
#          area_urban_sq_km  life_expectancy  adult_male_mortality_rate  \
# 6475259           36132.0           77.109                    151.616
# 6475260           36132.0           77.109                    151.616
# 6475261           36132.0           77.109                    151.616
# 6475262           36132.0           77.109                    151.616
# 6475263           36132.0           77.109                    151.616
#
#          adult_female_mortality_rate  pollution_mortality_rate  \
# 6475259                       77.999                      37.0
# 6475260                       77.999                      37.0
# 6475261                       77.999                      37.0
# 6475262                       77.999                      37.0
# 6475263                       77.999                      37.0
#
#          comorbidity_mortality_rate
# 6475259                        15.8
# 6475260                        15.8
# 6475261                        15.8
# 6475262                        15.8
# 6475263                        15.8
#
# [5 rows x 41 columns]

# %%
# Contar cuántas filas contienen valores nulos en cada columna
null_counts = df.isnull().sum()

# Filtrar solo las columnas que tienen valores nulos
columns_with_nulls = null_counts[null_counts > 0]

# Mostrar el recuento de filas con valores nulos por columna
print("Columns with null values and their counts:")
print(columns_with_nulls)
# Out:
# Columns with null values and their counts:
# cumulative_vaccine_doses_administered    575
# average_temperature_celsius                3
# relative_humidity                          3
# dtype: int64

# %%
# Contar cuántas filas contienen valores 0 en cada columna
columns_with_zeros = df.columns[(df == 0).any()]

# Crear un diccionario para almacenar el recuento de filas con valores 0
zero_counts = {column: (df[column] == 0).sum() for column in columns_with_zeros}

# Mostrar el recuento de filas con valores 0 por columna
print("\nColumns with zero values and their counts:")
for column, count in zero_counts.items():
    print(f"Column '{column}' has {count} rows with zero values.")

# Opcional: mostrar el diccionario completo de ceros
print("\nCounts of zero values per column:", zero_counts)
# Out:
# Columns with zero values and their counts:
# Column 'new_confirmed' has 109 rows with zero values.
# Column 'new_deceased' has 117 rows with zero values.
#
# Counts of zero values per column: {'new_confirmed': 109, 'new_deceased': 117}

# %% [markdown]
# #### Vamos a imputar las columnas que tienen valores nulos y ceros

# %%
# Contar cuántas filas contienen valores 0 en cada columna
columns_with_zeros = df.columns[(df == 0).any()]

# Crear un diccionario para almacenar el recuento de filas con valores 0
zero_counts = {column: (df[column] == 0).sum() for column in columns_with_zeros}

# Mostrar el recuento de filas con valores 0 por columna
print("\nColumns with zero values and their counts:")
for column, count in zero_counts.items():
    print(f"Column '{column}' has {count} rows with zero values.")

# Opcional: mostrar el diccionario completo de ceros
print("\nCounts of zero values per column:", zero_counts)
# Out:
# Columns with zero values and their counts:
# Column 'new_confirmed' has 109 rows with zero values.
# Column 'new_deceased' has 117 rows with zero values.
#
# Counts of zero values per column: {'new_confirmed': 109, 'new_deceased': 117}

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df.describe()
# Out:
#        new_confirmed  new_deceased  cumulative_vaccine_doses_administered  \
# count         909.00        909.00                                 334.00
# mean         6930.25        181.57                            37297040.70
# std          8065.96        178.66                            28263160.97
# min             0.00          0.00                                  18.00
# 25%           679.00         25.00                             8334595.75
# 50%          3860.00        142.00                            35920610.50
# 75%         10125.00        261.00                            63741908.25
# max         40415.00        716.00                            87566541.00
#
#        population  population_male  population_female  population_density  \
# count      909.00           909.00             909.00              909.00
# mean  50882884.00      24984564.00        25898320.00               45.86
# std          0.00             0.00               0.00                0.00
# min   50882884.00      24984564.00        25898320.00               45.86
# 25%   50882884.00      24984564.00        25898320.00               45.86
# 50%   50882884.00      24984564.00        25898320.00               45.86
# 75%   50882884.00      24984564.00        25898320.00               45.86
# max   50882884.00      24984564.00        25898320.00               45.86
#
#        human_development_index  population_age_00_09  population_age_10_19  \
# count                   909.00                909.00                909.00
# mean                      0.75            7414155.00            8119876.00
# std                       0.00                  0.00                  0.00
# min                       0.75            7414155.00            8119876.00
# 25%                       0.75            7414155.00            8119876.00
# 50%                       0.75            7414155.00            8119876.00
# 75%                       0.75            7414155.00            8119876.00
# max                       0.75            7414155.00            8119876.00
#
#        ...  average_temperature_celsius  relative_humidity  \
# count  ...                       906.00             906.00
# mean   ...                        20.34              75.38
# std    ...                         3.40               7.27
# min    ...                        11.44              51.89
# 25%    ...                        18.64              70.20
# 50%    ...                        21.20              75.78
# 75%    ...                        22.89              80.18
# max    ...                        26.34              96.06
#
#        population_largest_city  area_rural_sq_km  area_urban_sq_km  \
# count                   909.00            909.00            909.00
# mean               10779376.00        1090598.00          36132.00
# std                       0.00              0.00              0.00
# min                10779376.00        1090598.00          36132.00
# 25%                10779376.00        1090598.00          36132.00
# 50%                10779376.00        1090598.00          36132.00
# 75%                10779376.00        1090598.00          36132.00
# max                10779376.00        1090598.00          36132.00
#
#        life_expectancy  adult_male_mortality_rate  \
# count           909.00                     909.00
# mean             77.11                     151.62
# std               0.00                       0.00
# min              77.11                     151.62
# 25%              77.11                     151.62
# 50%              77.11                     151.62
# 75%              77.11                     151.62
# max              77.11                     151.62
#
#        adult_female_mortality_rate  pollution_mortality_rate  \
# count                       909.00                    909.00
# mean                         78.00                     37.00
# std                           0.00                      0.00
# min                          78.00                     37.00
# 25%                          78.00                     37.00
# 50%                          78.00                     37.00
# 75%                          78.00                     37.00
# max                          78.00                     37.00
#
#        comorbidity_mortality_rate
# count                      909.00
# mean                        15.80
# std                          0.00
# min                         15.80
# 25%                         15.80
# 50%                         15.80
# 75%                         15.80
# max                         15.80
#
# [8 rows x 37 columns]

# %%
df['cumulative_vaccine_doses_administered'].fillna(0, inplace=True)
# Out:
# C:\Users\Kuma\AppData\Local\Temp\ipykernel_8860\628870301.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cumulative_vaccine_doses_administered'].fillna(0, inplace=True)

# %%
df.isna().sum()
# Out:
# location_key                             0
# date                                     0
# country_code                             0
# country_name                             0
# new_confirmed                            0
# new_deceased                             0
# cumulative_vaccine_doses_administered    0
# population                               0
# population_male                          0
# population_female                        0
# population_density                       0
# human_development_index                  0
# population_age_00_09                     0
# population_age_10_19                     0
# population_age_20_29                     0
# population_age_30_39                     0
# population_age_40_49                     0
# population_age_50_59                     0
# population_age_60_69                     0
# population_age_70_79                     0
# population_age_80_and_older              0
# gdp_usd                                  0
# gdp_per_capita_usd                       0
# latitude                                 0
# longitude                                0
# area_sq_km                               0
# smoking_prevalence                       0
# diabetes_prevalence                      0
# infant_mortality_rate                    0
# nurses_per_1000                          0
# physicians_per_1000                      0
# average_temperature_celsius              3
# relative_humidity                        3
# population_largest_city                  0
# area_rural_sq_km                         0
# area_urban_sq_km                         0
# life_expectancy                          0
# adult_male_mortality_rate                0
# adult_female_mortality_rate              0
# pollution_mortality_rate                 0
# comorbidity_mortality_rate               0
# dtype: int64

# %%
df.to_csv('covid19_Colombia.csv', index=False)
