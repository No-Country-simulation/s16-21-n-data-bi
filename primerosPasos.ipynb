# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Autenticación y autorización
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# ID del archivo en Google Drive (extraído del enlace de Google Drive)
file_id = '1DLTyGzpIqBm7SOPHGD9OnHVKYID4hm9M'

# Descargar el archivo desde Google Drive
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('data_latinoamerica.csv')  # Guardar como data_latinoamerica.csv en Colab

# %%
import pandas as pd

# Nombre del archivo que deseas cargar
filename_part1 = 'part1_data.csv'

# Cargar el archivo CSV en un DataFrame
df_part1 = pd.read_csv(filename_part1)

# Mostrar las primeras filas del DataFrame
df_part1.head()

# Obtener información del DataFrame
df_part1.info()

# Obtener estadísticas descriptivas
df_part1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49999 entries, 0 to 49998
# Data columns (total 50 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   location_key                           49999 non-null  object
#  1   date                                   49999 non-null  object
#  2   country_code                           49999 non-null  object
#  3   country_name                           49999 non-null  object
#  4   new_confirmed                          35136 non-null  float64
#  5   new_deceased                           35136 non-null  float64
#  6   cumulative_confirmed                   35136 non-null  float64
#  7   cumulative_deceased                    35136 non-null  float64
#  8   cumulative_vaccine_doses_administered  22826 non-null  float64
#  9   population                             49999 non-null  float64
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación
df_matriz_correlacion = df.corr()

# Obtener las variables más correlacionadas (absolutas) con otras variables
correlation_values = df_matriz_correlacion.abs().unstack().sort_values(ascending=False)
most_correlated = correlation_values[correlation_values != 1].drop_duplicates().head(10)

# %%
import pandas as pd



# Calcular la matriz de correlación
df_matriz_correlacion = df.corr()

# Obtener las variables más correlacionadas (absolutas) con otras variables
correlation_values = df_matriz_correlacion.abs().unstack().sort_values(ascending=False)
most_correlated = correlation_values[correlation_values != 1].drop_duplicates().head(10)

# Crear un DataFrame con las correlaciones más altas
df_most_correlated = pd.DataFrame({
    'Correlación': most_correlated.values,
    'Variable 1': [x[0] for x in most_correlated.index],
    'Variable 2': [x[1] for x in most_correlated.index]
})

# Mostrar el DataFrame con las correlaciones más altas
print("DataFrame con las correlaciones más altas:")
print(df_most_correlated)
# Out:
# DataFrame con las correlaciones más altas:
#    Correlación Variable 1  Variable 2
# 0     0.753270       6667   76.532612
# 1     0.319772        0.0   76.532612
# 2     0.299902       6667         0.0
# 3          NaN       6667  Unnamed: 3

# %%
import pandas as pd



# Calcular la matriz de correlación
df_matriz_correlacion = df.corr()

# Obtener los nombres de las columnas del DataFrame original
nombres_columnas = df.columns

# Mostrar los nombres de las columnas
print("Nombres de las columnas en el DataFrame:")
print(nombres_columnas)

# Mostrar la matriz de correlación como DataFrame
print("\nMatriz de Correlación:")
print(df_matriz_correlacion)

# Obtener las variables más correlacionadas (absolutas) con otras variables
correlation_values = df_matriz_correlacion.abs().unstack().sort_values(ascending=False)
most_correlated = correlation_values[correlation_values != 1].drop_duplicates().head(10)

# Mostrar las variables más correlacionadas en una tabla
print("\nVariables más significativamente correlacionadas (absolutas):")
print(most_correlated)
# Out:
# Nombres de las columnas en el DataFrame:
# Index(['6667', '0.0', '76.532612', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        '0.0.1', '0.0.2'],
#       dtype='object', name='Columnas')
#
# Matriz de Correlación:
# Columnas         6667       0.0  76.532612  Unnamed: 3  Unnamed: 4  \
# Columnas
# 6667         1.000000 -0.299902  -0.753270         NaN         NaN
# 0.0         -0.299902  1.000000   0.319772         NaN         NaN
# 76.532612   -0.753270  0.319772   1.000000         NaN         NaN
# Unnamed: 3        NaN       NaN        NaN         NaN         NaN
# Unnamed: 4        NaN       NaN        NaN         NaN         NaN
# Unnamed: 5        NaN       NaN        NaN         NaN         NaN
# Unnamed: 6        NaN       NaN        NaN         NaN         NaN
# Unnamed: 7        NaN       NaN        NaN         NaN         NaN
# ...
